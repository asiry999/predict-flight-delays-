# %%
#https://towardsdatascience.com/exploratory-data-analysis-eda-python-87178e35b14
#https://thispointer.com/pandas-skip-rows-while-reading-csv-file-to-a-dataframe-using-read_csv-in-python/
#import the useful libraries.
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#https://www.kaggle.com/what0919/diabetes-prediction

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/airlinesmall.csv')

# %%
# Printing the data
data
# Out:
#         Year  Month  DayofMonth  ...  NASDelay  SecurityDelay  LateAircraftDelay
# 0       1987     10          21  ...       NaN            NaN                NaN
# 1       1987     10          26  ...       NaN            NaN                NaN
# 2       1987     10          23  ...       NaN            NaN                NaN
# 3       1987     10          23  ...       NaN            NaN                NaN
# 4       1987     10          22  ...       NaN            NaN                NaN
# ...      ...    ...         ...  ...       ...            ...                ...
# 123518  2008     12           9  ...       NaN            NaN                NaN
# 123519  2008     12          10  ...      15.0            0.0                0.0
# 123520  2008     12          11  ...       NaN            NaN                NaN
# 123521  2008     12          12  ...       NaN            NaN                NaN
# 123522  2008     12          12  ...       NaN            NaN                NaN
#
# [123523 rows x 29 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123523 entries, 0 to 123522
# Data columns (total 29 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Year               123523 non-null  int64
#  1   Month              123523 non-null  int64
#  2   DayofMonth         123523 non-null  int64
#  3   DayOfWeek          123523 non-null  int64
#  4   DepTime            121172 non-null  float64
#  5   CRSDepTime         123523 non-null  int64
#  6   ArrTime            120867 non-null  float64
#  7   CRSArrTime         123523 non-null  int64
#  8   UniqueCarrier      123523 non-null  object
#  9   FlightNum          123523 non-null  int64
#  10  TailNum            86169 non-null   object
#  11  ActualElapsedTime  120866 non-null  float64
#  12  CRSElapsedTime     123491 non-null  float64
#  13  AirTime            84234 non-null   float64
#  14  ArrDelay           120866 non-null  float64
#  15  DepDelay           121172 non-null  float64
#  16  Origin             123523 non-null  object
#  17  Dest               123523 non-null  object
#  18  Distance           123319 non-null  float64
#  19  TaxiIn             86140 non-null   float64
#  20  TaxiOut            86159 non-null   float64
#  21  Cancelled          123523 non-null  int64
#  22  CancellationCode   703 non-null     object
#  23  Diverted           123523 non-null  int64
#  24  CarrierDelay       34254 non-null   float64
#  25  WeatherDelay       34254 non-null   float64
#  26  NASDelay           34254 non-null   float64
#  27  SecurityDelay      34254 non-null   float64
#  28  LateAircraftDelay  34254 non-null   float64
# dtypes: float64(15), int64(9), object(5)
# memory usage: 27.3+ MB

# %%
#import the useful libraries.
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Read the file in data without first two rows as it is of no use.
#data = pd.read_csv('/content/drive/MyDrive/diabetes.csv', skiprows=[0,2,5])
data1 = pd.read_csv('/content/drive/MyDrive/airlinesmall.csv', skiprows=[16,22,17])
#data = pd.read_csv("marketing_analysis.csv",skiprows = 2)
#print the head of the data frame.
data1.head()
# Out:
#    Year  Month  DayofMonth  ...  NASDelay  SecurityDelay  LateAircraftDelay
# 0  1987     10          21  ...       NaN            NaN                NaN
# 1  1987     10          26  ...       NaN            NaN                NaN
# 2  1987     10          23  ...       NaN            NaN                NaN
# 3  1987     10          23  ...       NaN            NaN                NaN
# 4  1987     10          22  ...       NaN            NaN                NaN
#
# [5 rows x 29 columns]

# %%
data1
# Out:
#         Year  Month  DayofMonth  ...  NASDelay  SecurityDelay  LateAircraftDelay
# 0       1987     10          21  ...       NaN            NaN                NaN
# 1       1987     10          26  ...       NaN            NaN                NaN
# 2       1987     10          23  ...       NaN            NaN                NaN
# 3       1987     10          23  ...       NaN            NaN                NaN
# 4       1987     10          22  ...       NaN            NaN                NaN
# ...      ...    ...         ...  ...       ...            ...                ...
# 123515  2008     12           9  ...       NaN            NaN                NaN
# 123516  2008     12          10  ...      15.0            0.0                0.0
# 123517  2008     12          11  ...       NaN            NaN                NaN
# 123518  2008     12          12  ...       NaN            NaN                NaN
# 123519  2008     12          12  ...       NaN            NaN                NaN
#
# [123520 rows x 29 columns]

# %%
# Drop the customer id as it is of no use.
data1.drop('Dest', axis = 1, inplace = True)

# %%
data1
# Out:
#         Year  Month  DayofMonth  ...  NASDelay  SecurityDelay  LateAircraftDelay
# 0       1987     10          21  ...       NaN            NaN                NaN
# 1       1987     10          26  ...       NaN            NaN                NaN
# 2       1987     10          23  ...       NaN            NaN                NaN
# 3       1987     10          23  ...       NaN            NaN                NaN
# 4       1987     10          22  ...       NaN            NaN                NaN
# ...      ...    ...         ...  ...       ...            ...                ...
# 123515  2008     12           9  ...       NaN            NaN                NaN
# 123516  2008     12          10  ...      15.0            0.0                0.0
# 123517  2008     12          11  ...       NaN            NaN                NaN
# 123518  2008     12          12  ...       NaN            NaN                NaN
# 123519  2008     12          12  ...       NaN            NaN                NaN
#
# [123520 rows x 28 columns]

# %%
# Drop the customer id as it is of no use.
data1.drop('TailNum', axis = 1, inplace = True)

# %%
data1
# Out:
#         Year  Month  DayofMonth  ...  NASDelay  SecurityDelay  LateAircraftDelay
# 0       1987     10          21  ...       NaN            NaN                NaN
# 1       1987     10          26  ...       NaN            NaN                NaN
# 2       1987     10          23  ...       NaN            NaN                NaN
# 3       1987     10          23  ...       NaN            NaN                NaN
# 4       1987     10          22  ...       NaN            NaN                NaN
# ...      ...    ...         ...  ...       ...            ...                ...
# 123515  2008     12           9  ...       NaN            NaN                NaN
# 123516  2008     12          10  ...      15.0            0.0                0.0
# 123517  2008     12          11  ...       NaN            NaN                NaN
# 123518  2008     12          12  ...       NaN            NaN                NaN
# 123519  2008     12          12  ...       NaN            NaN                NaN
#
# [123520 rows x 27 columns]

# %%
#Origin
data1.drop('Origin', axis = 1, inplace = True)

# %%
data1
# Out:
#         Year  Month  DayofMonth  ...  NASDelay  SecurityDelay  LateAircraftDelay
# 0       1987     10          21  ...       NaN            NaN                NaN
# 1       1987     10          26  ...       NaN            NaN                NaN
# 2       1987     10          23  ...       NaN            NaN                NaN
# 3       1987     10          23  ...       NaN            NaN                NaN
# 4       1987     10          22  ...       NaN            NaN                NaN
# ...      ...    ...         ...  ...       ...            ...                ...
# 123515  2008     12           9  ...       NaN            NaN                NaN
# 123516  2008     12          10  ...      15.0            0.0                0.0
# 123517  2008     12          11  ...       NaN            NaN                NaN
# 123518  2008     12          12  ...       NaN            NaN                NaN
# 123519  2008     12          12  ...       NaN            NaN                NaN
#
# [123520 rows x 26 columns]

# %%
#Extract job  & Education in newly from "jobedu" column.
#data['job']= data["jobedu"].apply(lambda x: x.split(",")[0])

# %%
# Checking the missing values
data1.isnull().sum()

#CRSElapsedTime
# Out:
# Year                      0
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                2351
# CRSDepTime                0
# ArrTime                2656
# CRSArrTime                0
# UniqueCarrier             0
# FlightNum                 0
# ActualElapsedTime      2657
# CRSElapsedTime           32
# AirTime               39286
# ArrDelay               2657
# DepDelay               2351
# Distance                204
# TaxiIn                37380
# TaxiOut               37361
# Cancelled                 0
# CancellationCode     122817
# Diverted                  0
# CarrierDelay          89266
# WeatherDelay          89266
# NASDelay              89266
# SecurityDelay         89266
# LateAircraftDelay     89266
# dtype: int64

# %%
# Dropping the records with CRSElapsedTime missing in data dataframe.
data1 = data1[~data1.CRSElapsedTime.isnull()].copy()

# Checking the missing values in the dataset.
data1.isnull().sum()


#CRSElapsedTime
# Out:
# Year                      0
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                2322
# CRSDepTime                0
# ArrTime                2624
# CRSArrTime                0
# UniqueCarrier             0
# FlightNum                 0
# ActualElapsedTime      2625
# CRSElapsedTime            0
# AirTime               39255
# ArrDelay               2625
# DepDelay               2322
# Distance                204
# TaxiIn                37380
# TaxiOut               37361
# Cancelled                 0
# CancellationCode     122785
# Diverted                  0
# CarrierDelay          89235
# WeatherDelay          89235
# NASDelay              89235
# SecurityDelay         89235
# LateAircraftDelay     89235
# dtype: int64

# %%
# Find the mode of month in data
airplan_driven_mode = data1.Diverted.mode()[0]

# Fill the missing values with mode value of month in data.
data1.Diverted.fillna(airplan_driven_mode, inplace = True)

# Let's see the null values in the month column.
data1.Diverted.isnull().sum()
# Out:
# 0

# %%
# Find the mode of month in data
airplan_driven_mode = data1.DepTime.mode()[0]

# Fill the missing values with mode value of month in data.
data1.DepTime.fillna(airplan_driven_mode, inplace = True)

# Let's see the null values in the month column.
data1.DepTime.isnull().sum()
# Out:
# 0

# %%
data1
# Out:
#         Year  Month  DayofMonth  ...  NASDelay  SecurityDelay  LateAircraftDelay
# 0       1987     10          21  ...       NaN            NaN                NaN
# 1       1987     10          26  ...       NaN            NaN                NaN
# 2       1987     10          23  ...       NaN            NaN                NaN
# 3       1987     10          23  ...       NaN            NaN                NaN
# 4       1987     10          22  ...       NaN            NaN                NaN
# ...      ...    ...         ...  ...       ...            ...                ...
# 123515  2008     12           9  ...       NaN            NaN                NaN
# 123516  2008     12          10  ...      15.0            0.0                0.0
# 123517  2008     12          11  ...       NaN            NaN                NaN
# 123518  2008     12          12  ...       NaN            NaN                NaN
# 123519  2008     12          12  ...       NaN            NaN                NaN
#
# [123488 rows x 26 columns]

# %%
#drop the records with response missing in data.
data1 = data1[~data1.DepTime.isnull()].copy()
# Calculate the missing values in each column of data frame
data1.isnull().sum()
# Out:
# Year                      0
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                   0
# CRSDepTime                0
# ArrTime                2624
# CRSArrTime                0
# UniqueCarrier             0
# FlightNum                 0
# ActualElapsedTime      2625
# CRSElapsedTime            0
# AirTime               39255
# ArrDelay               2625
# DepDelay               2322
# Distance                204
# TaxiIn                37380
# TaxiOut               37361
# Cancelled                 0
# CancellationCode     122785
# Diverted                  0
# CarrierDelay          89235
# WeatherDelay          89235
# NASDelay              89235
# SecurityDelay         89235
# LateAircraftDelay     89235
# dtype: int64

# %%
data1
# Out:
#         Year  Month  DayofMonth  ...  NASDelay  SecurityDelay  LateAircraftDelay
# 0       1987     10          21  ...       NaN            NaN                NaN
# 1       1987     10          26  ...       NaN            NaN                NaN
# 2       1987     10          23  ...       NaN            NaN                NaN
# 3       1987     10          23  ...       NaN            NaN                NaN
# 4       1987     10          22  ...       NaN            NaN                NaN
# ...      ...    ...         ...  ...       ...            ...                ...
# 123515  2008     12           9  ...       NaN            NaN                NaN
# 123516  2008     12          10  ...      15.0            0.0                0.0
# 123517  2008     12          11  ...       NaN            NaN                NaN
# 123518  2008     12          12  ...       NaN            NaN                NaN
# 123519  2008     12          12  ...       NaN            NaN                NaN
#
# [123488 rows x 26 columns]

# %%
#groupby the response to find the mean of the salary with response no & yes separately.
data1.groupby('Cancelled')['DepTime'].mean()
# Out:
# Cancelled
# 0    1349.504642
# 1     700.129143
# Name: DepTime, dtype: float64

# %%
#groupby the response to find the mean of the salary with response no & yes separately.
data.groupby('Cancelled')['DepTime'].mean()
# Out:
# Cancelled
# 0    1349.499979
# 1    1000.000000
# Name: DepTime, dtype: float64

# %%
#groupby the response to find the median of the salary with response no & yes separately.
data1.groupby('Distance')['Cancelled'].median()
# Out:
# Distance
# 11.0      0.0
# 21.0      0.0
# 24.0      0.0
# 25.0      0.0
# 28.0      0.0
#          ...
# 4213.0    0.0
# 4243.0    0.0
# 4433.0    0.0
# 4502.0    0.0
# 4962.0    0.0
# Name: Cancelled, Length: 1467, dtype: float64

# %%
#groupby the response to find the median of the salary with response no & yes separately.
data.groupby('Distance')['Cancelled'].median()
# Out:
# Distance
# 11.0      0.0
# 21.0      0.0
# 24.0      0.0
# 25.0      0.0
# 28.0      0.0
#          ...
# 4213.0    0.0
# 4243.0    0.0
# 4433.0    0.0
# 4502.0    0.0
# 4962.0    0.0
# Name: Cancelled, Length: 1467, dtype: float64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123488 entries, 0 to 123519
# Data columns (total 26 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Year               123488 non-null  int64
#  1   Month              123488 non-null  int64
#  2   DayofMonth         123488 non-null  int64
#  3   DayOfWeek          123488 non-null  int64
#  4   DepTime            123488 non-null  float64
#  5   CRSDepTime         123488 non-null  int64
#  6   ArrTime            120864 non-null  float64
#  7   CRSArrTime         123488 non-null  int64
#  8   UniqueCarrier      123488 non-null  object
#  9   FlightNum          123488 non-null  int64
#  10  ActualElapsedTime  120863 non-null  float64
#  11  CRSElapsedTime     123488 non-null  float64
#  12  AirTime            84233 non-null   float64
#  13  ArrDelay           120863 non-null  float64
#  14  DepDelay           121166 non-null  float64
#  15  Distance           123284 non-null  float64
#  16  TaxiIn             86108 non-null   float64
#  17  TaxiOut            86127 non-null   float64
#  18  Cancelled          123488 non-null  int64
#  19  CancellationCode   703 non-null     object
#  20  Diverted           123488 non-null  int64
#  21  CarrierDelay       34253 non-null   float64
#  22  WeatherDelay       34253 non-null   float64
#  23  NASDelay           34253 non-null   float64
#  24  SecurityDelay      34253 non-null   float64
#  25  LateAircraftDelay  34253 non-null   float64
# dtypes: float64(15), int64(9), object(2)
# memory usage: 25.4+ MB

# %%
data1.Cancelled
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 123515    0
# 123516    0
# 123517    0
# 123518    0
# 123519    0
# Name: Cancelled, Length: 123488, dtype: int64

# %%
data1.FlightNum
# Out:
# 0         1503
# 1         1550
# 2         1589
# 3         1655
# 4         1702
#           ...
# 123515    1668
# 123516    1385
# 123517    1074
# 123518     782
# 123519    1790
# Name: FlightNum, Length: 123488, dtype: int64

# %%
#plot the box plot of salary for yes & no responses.
sns.boxplot(data1.AirTime, data1. DepDelay)
plt.show()

# %%
#	Pregnancies	Glucose	BloodPressure	BMI	DiabetesPedigreeFunction	Age	Outcome
result = pd.pivot_table(data=data1, index='FlightNum', columns='Cancelled',values='DepTime')
print(result)

#create heat map of education vs marital vs response_rate
sns.heatmap(result, annot=True, cmap = 'RdYlGn', center=0.117)
plt.show()
# Out:
# Cancelled            0      1
# FlightNum
# 1          1040.135135    NaN
# 2          1270.923077  700.0
# 3          1175.833333  700.0
# 4          1171.197183  700.0
# 5          1118.913580  700.0
# ...                ...    ...
# 9576       1105.000000    NaN
# 9577       1424.000000    NaN
# 9578       1359.000000    NaN
# 9579       1740.000000    NaN
# 9581       2100.000000    NaN
#
# [7070 rows x 2 columns]

# %%
data1
# Out:
#         Year  Month  DayofMonth  ...  NASDelay  SecurityDelay  LateAircraftDelay
# 0       1987     10          21  ...       NaN            NaN                NaN
# 1       1987     10          26  ...       NaN            NaN                NaN
# 2       1987     10          23  ...       NaN            NaN                NaN
# 3       1987     10          23  ...       NaN            NaN                NaN
# 4       1987     10          22  ...       NaN            NaN                NaN
# ...      ...    ...         ...  ...       ...            ...                ...
# 123515  2008     12           9  ...       NaN            NaN                NaN
# 123516  2008     12          10  ...      15.0            0.0                0.0
# 123517  2008     12          11  ...       NaN            NaN                NaN
# 123518  2008     12          12  ...       NaN            NaN                NaN
# 123519  2008     12          12  ...       NaN            NaN                NaN
#
# [123488 rows x 26 columns]

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
#print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as matplot

import re
import sklearn

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
data1.describe()
# Out:
#                 Year          Month  ...  SecurityDelay  LateAircraftDelay
# count  123488.000000  123488.000000  ...   34253.000000       34253.000000
# mean     1998.625194       6.554337  ...       0.022889           4.672583
# std         6.227237       3.443940  ...       1.366292          19.611491
# min      1987.000000       1.000000  ...       0.000000           0.000000
# 25%      1993.000000       4.000000  ...       0.000000           0.000000
# 50%      1999.000000       7.000000  ...       0.000000           0.000000
# 75%      2004.000000      10.000000  ...       0.000000           0.000000
# max      2008.000000      12.000000  ...     181.000000         507.000000
#
# [8 rows x 24 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123488 entries, 0 to 123519
# Data columns (total 25 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Year               123488 non-null  int64
#  1   Month              123488 non-null  int64
#  2   DayofMonth         123488 non-null  int64
#  3   DayOfWeek          123488 non-null  int64
#  4   DepTime            123488 non-null  float64
#  5   CRSDepTime         123488 non-null  int64
#  6   ArrTime            120864 non-null  float64
#  7   CRSArrTime         123488 non-null  int64
#  8   FlightNum          123488 non-null  int64
#  9   ActualElapsedTime  120863 non-null  float64
#  10  CRSElapsedTime     123488 non-null  float64
#  11  AirTime            84233 non-null   float64
#  12  ArrDelay           120863 non-null  float64
#  13  DepDelay           121166 non-null  float64
#  14  Distance           123284 non-null  float64
#  15  TaxiIn             86108 non-null   float64
#  16  TaxiOut            86127 non-null   float64
#  17  Cancelled          123488 non-null  int64
#  18  CancellationCode   703 non-null     object
#  19  Diverted           123488 non-null  int64
#  20  CarrierDelay       34253 non-null   float64
#  21  WeatherDelay       34253 non-null   float64
#  22  NASDelay           34253 non-null   float64
#  23  SecurityDelay      34253 non-null   float64
#  24  LateAircraftDelay  34253 non-null   float64
# dtypes: float64(15), int64(9), object(1)
# memory usage: 29.5+ MB

# %%
#data1.drop(['UniqueCarrier'], axis = 1, inplace=True)
data1.drop(['CancellationCode'], axis = 1, inplace=True)

# %%
df=data1
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123488 entries, 0 to 123519
# Data columns (total 24 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Year               123488 non-null  int64
#  1   Month              123488 non-null  int64
#  2   DayofMonth         123488 non-null  int64
#  3   DayOfWeek          123488 non-null  int64
#  4   DepTime            123488 non-null  float64
#  5   CRSDepTime         123488 non-null  int64
#  6   ArrTime            120864 non-null  float64
#  7   CRSArrTime         123488 non-null  int64
#  8   FlightNum          123488 non-null  int64
#  9   ActualElapsedTime  120863 non-null  float64
#  10  CRSElapsedTime     123488 non-null  float64
#  11  AirTime            84233 non-null   float64
#  12  ArrDelay           120863 non-null  float64
#  13  DepDelay           121166 non-null  float64
#  14  Distance           123284 non-null  float64
#  15  TaxiIn             86108 non-null   float64
#  16  TaxiOut            86127 non-null   float64
#  17  Cancelled          123488 non-null  int64
#  18  Diverted           123488 non-null  int64
#  19  CarrierDelay       34253 non-null   float64
#  20  WeatherDelay       34253 non-null   float64
#  21  NASDelay           34253 non-null   float64
#  22  SecurityDelay      34253 non-null   float64
#  23  LateAircraftDelay  34253 non-null   float64
# dtypes: float64(15), int64(9)
# memory usage: 28.6 MB

# %%
df.describe()
# Out:
#                 Year          Month  ...  SecurityDelay  LateAircraftDelay
# count  123488.000000  123488.000000  ...   34253.000000       34253.000000
# mean     1998.625194       6.554337  ...       0.022889           4.672583
# std         6.227237       3.443940  ...       1.366292          19.611491
# min      1987.000000       1.000000  ...       0.000000           0.000000
# 25%      1993.000000       4.000000  ...       0.000000           0.000000
# 50%      1999.000000       7.000000  ...       0.000000           0.000000
# 75%      2004.000000      10.000000  ...       0.000000           0.000000
# max      2008.000000      12.000000  ...     181.000000         507.000000
#
# [8 rows x 24 columns]

# %%
from sklearn.feature_selection import VarianceThreshold

df.dropna(axis=1, how='all')
df.dropna(axis=0, how='all')
"""
df = df.rename(columns = {'Year' : 'Year_tr',
                          'Month' : 'Month_tr',
                          'DayofMonth' : 'DayofMonth_tr', 
                          'DayOfWeek' : 'DayOfWeek_tr',
                          'DepTime' : 'DepTime_tr',
                          'CRSDepTime' : 'CRSDepTime_tr',
                          'ArrTime' : 'ArrTime_tr',
                          'CRSArrTime' : 'CRSArrTime_tr',
                          'FlightNum' : 'FlightNum_tr',
                          'ActualElapsedTime' : 'ActualElapsedTime_tr',
                          'CRSElapsedTime' : 'CRSElapsedTime_tr',
                          'AirTime' : 'AirTime_tr',
                          'ArrDelay' : 'ArrDelay_tr',
                          'DepDelay' : 'DepDelay_tr',
                          'Distance' : 'Distance_tr',
                          'TaxiIn' : 'TaxiIn_tr',
                          'Cancelled' : 'Cancelled_tr',
                          'Diverted' : 'Diverted_tr',
                          'CarrierDelay' : 'CarrierDelay_tr',
                          'WeatherDelay' : 'WeatherDelay_tr',
                          'NASDelay' : 'NASDelay_tr',
                          'SecurityDelay' : 'SecurityDelay_tr',
                          'CancellationCode' : 'CancellationCode_tr',
                          'LateAircraftDelay' : 'LateAircraftDelay_tr'                        
                          })
"""
# Out:
# "\ndf = df.rename(columns = {'Year' : 'Year_tr',\n                          'Month' : 'Month_tr',\n                          'DayofMonth' : 'DayofMonth_tr', \n                          'DayOfWeek' : 'DayOfWeek_tr',\n                          'DepTime' : 'DepTime_tr',\n                          'CRSDepTime' : 'CRSDepTime_tr',\n                          'ArrTime' : 'ArrTime_tr',\n                          'CRSArrTime' : 'CRSArrTime_tr',\n                          'FlightNum' : 'FlightNum_tr',\n                          'ActualElapsedTime' : 'ActualElapsedTime_tr',\n                          'CRSElapsedTime' : 'CRSElapsedTime_tr',\n                          'AirTime' : 'AirTime_tr',\n                          'ArrDelay' : 'ArrDelay_tr',\n                          'DepDelay' : 'DepDelay_tr',\n                          'Distance' : 'Distance_tr',\n                          'TaxiIn' : 'TaxiIn_tr',\n                          'Cancelled' : 'Cancelled_tr',\n                          'Diverted' : 'Diverted_tr',\n                          'CarrierDelay' : 'CarrierDelay_tr',\n                          'WeatherDelay' : 'WeatherDelay_tr',\n                          'NASDelay' : 'NASDelay_tr',\n                          'SecurityDelay' : 'SecurityDelay_tr',\n                          'CancellationCode' : 'CancellationCode_tr',\n                          'LateAircraftDelay' : 'LateAircraftDelay_tr'                        \n                          })\n"

# %%
#df = df.loc[:, ['Year_tr', 'Month_tr', 'DayofMonth_tr', 'DayOfWeek_tr','DepTime_tr',    'CRSDepTime_tr', 'ArrTime_tr', 'CRSArrTime_tr', 'FlightNum_tr',       'ActualElapsedTime_tr', 'CRSElapsedTime_tr','AirTime_tr', 'ArrDelay_tr', 'DepDelay_tr',            'Distance_tr', 'TaxiIn_tr', 'TaxiOut_tr', 'Cancelled_tr', 'CancellationCode_tr',  'Diverted_tr',               'CarrierDelay_tr', 'WeatherDelay_tr', 'NASDelay_tr', 'SecurityDelay_tr', 'LateAircraftDelay_tr']]
#Cancelled
df = df.loc[:, ['DepTime', 'CRSDepTime']]
#	Year	Month	DayofMonth	DayOfWeek	DepTime	CRSDepTime	ArrTime	CRSArrTime	FlightNum	ActualElapsedTime	CRSElapsedTime	AirTime	ArrDelay	DepDelay	Distance	TaxiIn	TaxiOut	Cancelled	CancellationCode	Diverted	CarrierDelay	WeatherDelay	NASDelay	SecurityDelay	LateAircraftDelay
#	Year	Month	DayofMonth	DayOfWeek	DepTime	CRSDepTime	ArrTime	CRSArrTime	FlightNum	ActualElapsedTime	CRSElapsedTime	AirTime	ArrDelay	DepDelay	Distance	TaxiIn	TaxiOut	Cancelled	CancellationCode	Diverted	CarrierDelay	WeatherDelay	NASDelay	SecurityDelay	LateAircraftDelay
df.describe()
# Out:
#              DepTime     CRSDepTime
# count  123488.000000  123488.000000
# mean     1337.288886    1335.487456
# std       483.022091     477.584797
# min         1.000000       0.000000
# 25%       920.000000     927.000000
# 50%      1327.000000    1330.000000
# 75%      1735.000000    1730.000000
# max      2505.000000    2359.000000

# %%
from sklearn.feature_selection import VarianceThreshold

#year in us -> american : 0, not american : 1
df.dropna(axis=1, how='all')
df.dropna(axis=0, how='all')
# Out:
#         DepTime  CRSDepTime
# 0         642.0         630
# 1        1021.0        1020
# 2        2055.0        2035
# 3        1332.0        1320
# 4         629.0         630
# ...         ...         ...
# 123515   1701.0        1705
# 123516   1228.0        1230
# 123517   2259.0        2300
# 123518    706.0         705
# 123519   2140.0        2129
#
# [123488 rows x 2 columns]

# %%
df['DepTime'] = df['DepTime'].fillna(value = 0)

# %%
df.describe()
# Out:
#              DepTime     CRSDepTime
# count  123488.000000  123488.000000
# mean     1337.288886    1335.487456
# std       483.022091     477.584797
# min         1.000000       0.000000
# 25%       920.000000     927.000000
# 50%      1327.000000    1330.000000
# 75%      1735.000000    1730.000000
# max      2505.000000    2359.000000

# %%
data1.loc[data1['DepTime'] <= 6, 'DepTime'] = 0.0
data.head(10)
# Out:
#    Year  Month  DayofMonth  ...  NASDelay  SecurityDelay  LateAircraftDelay
# 0  1987     10          21  ...       NaN            NaN                NaN
# 1  1987     10          26  ...       NaN            NaN                NaN
# 2  1987     10          23  ...       NaN            NaN                NaN
# 3  1987     10          23  ...       NaN            NaN                NaN
# 4  1987     10          22  ...       NaN            NaN                NaN
# 5  1987     10          28  ...       NaN            NaN                NaN
# 6  1987     10           8  ...       NaN            NaN                NaN
# 7  1987     10          10  ...       NaN            NaN                NaN
# 8  1987     10          20  ...       NaN            NaN                NaN
# 9  1987     10          15  ...       NaN            NaN                NaN
#
# [10 rows x 29 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123488 entries, 0 to 123519
# Data columns (total 25 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Year               123488 non-null  int64
#  1   Month              123488 non-null  int64
#  2   DayofMonth         123488 non-null  int64
#  3   DayOfWeek          123488 non-null  int64
#  4   DepTime            123488 non-null  float64
#  5   CRSDepTime         123488 non-null  int64
#  6   ArrTime            120864 non-null  float64
#  7   CRSArrTime         123488 non-null  int64
#  8   FlightNum          123488 non-null  int64
#  9   ActualElapsedTime  120863 non-null  float64
#  10  CRSElapsedTime     123488 non-null  float64
#  11  AirTime            84233 non-null   float64
#  12  ArrDelay           120863 non-null  float64
#  13  DepDelay           121166 non-null  float64
#  14  Distance           123284 non-null  float64
#  15  TaxiIn             86108 non-null   float64
#  16  TaxiOut            86127 non-null   float64
#  17  Cancelled          123488 non-null  int64
#  18  CancellationCode   703 non-null     object
#  19  Diverted           123488 non-null  int64
#  20  CarrierDelay       34253 non-null   float64
#  21  WeatherDelay       34253 non-null   float64
#  22  NASDelay           34253 non-null   float64
#  23  SecurityDelay      34253 non-null   float64
#  24  LateAircraftDelay  34253 non-null   float64
# dtypes: float64(15), int64(9), object(1)
# memory usage: 29.5+ MB

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(10,10))
sns.heatmap(data1.astype(float).drop(axis=1, labels='DepTime').corr(), linewidths=0.1, vmax=1.0, square=True, cmap=colormap, annot=True)

# %%
#show = sns.pairplot(df.drop(['ID', 'GlycoHemoglobin'], axis=1), hue='Diabetes', size=1.5, diag_kind='kde')
show = sns.pairplot(df, hue='DepTime', size=3.5, diag_kind='kde')

show.set(xticklabels=[])

# %%
#show = sns.pairplot(df.drop(['ID', 'GlycoHemoglobin'], axis=1), hue='Diabetes', size=1.5, diag_kind='kde')
show = sns.pairplot(df, hue='CRSDepTime', size=3.5, diag_kind='kde')

show.set(xticklabels=[])

# %%
from sklearn import linear_model
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
#from sklearn.cross_validation import KFold
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
sns.lmplot(x ="DepTime", y ="Distance", data = data1, order = 2, ci = None)

# %%
import pandas as pd

def clean_dataset(data1):
    assert isinstance(data1, pd.DataFrame), "data1 needs to be a pd.DataFrame"
    data1.dropna(inplace=True)
    indices_to_keep = ~data1.isin([np.nan, np.inf, -np.inf]).any(1)
    return data1[indices_to_keep].astype(np.float64)

# %%
X = np.array(data1['DepTime']).reshape(-1, 1)
y = np.array(data1['Distance']).reshape(-1, 1)
  
# Separating the data into independent and dependent variables
# Converting each dataframe into a numpy array 
# since each dataframe contains only one column
data1.dropna(inplace = True)
  
# Dropping any rows with Nan values
train_X, test_X, train_Y, test_Y = train_test_split(X, y, test_size = 0.25)
  
# Splitting the data into training and testing data
regr = LinearRegression()
  
regr.fit(train_X, train_Y)
print(regr.score(test_X, test_Y))
# Out:
# 0.000881137319725056

# %%
y_pred = regr.predict(test_X)
plt.scatter(test_X, test_Y, color ='b')
plt.plot(test_X, y_pred, color ='k')
  
plt.show()
# Data scatter of predicted values

# %%
#create linear regression obj
lr_regr = linear_model.LinearRegression()

#training via linear regression model
lr_regr.fit(train_X, train_Y)

#make prediction using the test set
lr_pred_diabetes = lr_regr.predict(test_X)
lr_score = lr_regr.score(test_X, test_Y)

print('LRr_Coefficients: ', lr_regr.coef_)
print('LR_Mean Square Error: %.2f' % mean_squared_error(test_Y, lr_pred_diabetes))
print('LR_Variance score: %.2f' % r2_score(test_Y, lr_pred_diabetes))
print('Score: %.2f' % lr_regr.score(test_X, test_Y))
# Out:
# LRr_Coefficients:  [[-0.03283171]]
# LR_Mean Square Error: 324658.54
# LR_Variance score: 0.00
# Score: 0.00
